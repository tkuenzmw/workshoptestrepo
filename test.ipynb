% %%
res = pyrunfile("test.py","mean_value",N=7);
% Out:
% Generated 7x7 Matrix:
% [[78 61 39 32 66 66 83]
%  [48 16 50  5 20 36 54]
%  [57 63 40 67 30 96 10]
%  [79 43  1 86 71 30  6]
%  [93 21  8 94 25 91 28]
%  [12 37 90 11 65 36 67]
%  [52 36 70 36 88 11 76]]
% Mean of all elements: 48.57142857142857
